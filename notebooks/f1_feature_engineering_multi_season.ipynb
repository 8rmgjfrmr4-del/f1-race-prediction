# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/f1_multi_season_raw.csv")

df = df.rename(columns={
    "Circuit.circuitId": "circuit_id"
})

df.shape
# Out:
# (300, 32)

# %%
df.head()
# Out:
#    number  position positionText  points  grid  laps    status  \
# 0      44         1            1      25     2    56  Finished
# 1      33         2            2      18     1    56  Finished
# 2      77         3            3      16     3    56  Finished
# 3       4         4            4      12     7    56  Finished
# 4      11         5            5      10     0    56  Finished
#
#   Driver.driverId  Driver.permanentNumber Driver.code  ... FastestLap.lap  \
# 0        hamilton                      44         HAM  ...           44.0
# 1  max_verstappen                      33         VER  ...           41.0
# 2          bottas                      77         BOT  ...           56.0
# 3          norris                       4         NOR  ...           38.0
# 4           perez                      11         PER  ...           44.0
#
#   FastestLap.Time.time FastestLap.AverageSpeed.units  \
# 0             1:34.015                           kph
# ...
